# %% [markdown]
# ## Import Libraries

# %%
import os
from openai import OpenAI
from lightrag import LightRAG, QueryParam
from lightrag.llm.openai import gpt_4o_complete, gpt_4o_mini_complete, openai_embed
import gradio as gr
from dotenv import load_dotenv
from IPython.display import Markdown, Image
import nest_asyncio
nest_asyncio.apply()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 import os
#       2 from openai import OpenAI
# ----> 3 from lightrag import LightRAG, QueryParam
#       4 from lightrag.llm.openai import gpt_4o_complete, gpt_4o_mini_complete, openai_embed
#       5 import gradio as gr
#
# File ~/Harish_MAC/Learning/Projects/GenAI/.venv/lib/python3.11/site-packages/lightrag/__init__.py:1
# ----> 1 from .lightrag import LightRAG as LightRAG, QueryParam as QueryParam
#       3 __version__ = "1.1.1"
#       4 __author__ = "Zirui Guo"
#
# File ~/Harish_MAC/Learning/Projects/GenAI/.venv/lib/python3.11/site-packages/lightrag/lightrag.py:9
#       6 from functools import partial
#       7 from typing import Type, cast, Dict
# ----> 9 from .llm import (
#      10     gpt_4o_mini_complete,
#      11     openai_embedding,
#      12 )
#      13 from .operate import (
#      14     chunking_by_token_size,
#      15     extract_entities,
#    (...)     19     mix_kg_vector_query,
#      20 )
#      22 from .utils import (
#      23     EmbeddingFunc,
#      24     compute_mdhash_id,
#    (...)     28     set_logger,
#      29 )
#
# File ~/Harish_MAC/Learning/Projects/GenAI/.venv/lib/python3.11/site-packages/lightrag/llm.py:13
#      11 import numpy as np
#      12 import ollama
# ---> 13 import torch
#      14 from openai import (
#      15     AsyncOpenAI,
#      16     APIConnectionError,
#    (...)     19     AsyncAzureOpenAI,
#      20 )
#      21 from pydantic import BaseModel, Field
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# ## LightRAG setup

# %%
def get_file_list(dir_path):
    
    file_list = []
    for root, dirs, files in os.walk(dir_path):
        for file in files:
            file_path = os.path.join(root, file)
            file_type = os.path.basename(os.path.dirname(file_path))
            file_name = os.path.basename(file_path)
            file_list.append({
                "file_path": file_path,
                "file_type": file_type,
                "file_name": file_name
            })
    return file_list

def extract_text_from_file(file_path):
    print(f"Extracting text from {file_path}...")
    try:
        with open(file_path, 'rb') as f:
            content = f.read()
        # Try to decode with error handling
        text = content.decode('utf-8', errors='ignore')
        return text
    except Exception as e:
        print(f"Failed to read file {file_path} with any encoding: {e}")
        return f"Error reading file: {file_path}"

# %%
base_dir = "/Users/harish/Harish_MAC/Learning/Projects/GenAI/unstructured_RAG"

working_dir =os.path.join(base_dir, "working_dir")

if not os.path.exists(working_dir):
  os.mkdir(working_dir)

load_dotenv(override=True)
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

lightrag = LightRAG(
    working_dir = working_dir,
    llm_model_func=gpt_4o_mini_complete,
    embedding_func=openai_embed,
    chunk_token_size=300,
    chunk_overlap_token_size=50,
    log_level="DEBUG"
)

dir_path = os.path.join(base_dir, "knowledge-base")
print(dir_path)

file_list = get_file_list(dir_path)

for file in file_list:
  print(f"Inserting {file['file_path']} into the database...")
  with open(file["file_path"], "r", encoding="utf-8") as f:
    lightrag.insert(f.read())
# Out:
# <string>:37: UserWarning: WARNING: log_level parameter is deprecated, use setup_logger in utils.py instead
# INFO: Process 25995 Shared-Data already initialized (multiprocess=False)
# INFO:nano-vectordb:Init {'embedding_dim': 1536, 'metric': 'cosine', 'storage_file': '/Users/harish/Harish_MAC/Learning/Projects/GenAI/unstructured_RAG/working_dir/vdb_entities.json'} 0 data
# INFO:nano-vectordb:Init {'embedding_dim': 1536, 'metric': 'cosine', 'storage_file': '/Users/harish/Harish_MAC/Learning/Projects/GenAI/unstructured_RAG/working_dir/vdb_relationships.json'} 0 data
# INFO:nano-vectordb:Init {'embedding_dim': 1536, 'metric': 'cosine', 'storage_file': '/Users/harish/Harish_MAC/Learning/Projects/GenAI/unstructured_RAG/working_dir/vdb_chunks.json'} 0 data
# /Users/harish/Harish_MAC/Learning/Projects/GenAI/unstructured_RAG/knowledge-base
# Inserting /Users/harish/Harish_MAC/Learning/Projects/GenAI/unstructured_RAG/knowledge-base/products/Rellm.md into the database...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 28
#      26 print(f"Inserting {file['file_path']} into the database...")
#      27 with open(file["file_path"], "r", encoding="utf-8") as f:
# ---> 28   lightrag.insert(f.read())
#
# File ~/Harish_MAC/Learning/Projects/GenAI/.venv/lib/python3.13/site-packages/lightrag/lightrag.py:572, in LightRAG.insert(self, input, split_by_character, split_by_character_only, ids, file_paths)
#     560 """Sync Insert documents with checkpoint support
#     561
#     562 Args:
#    (...)    569     file_paths: single string of the file path or list of file paths, used for citation
#     570 """
#     571 loop = always_get_an_event_loop()
# --> 572 loop.run_until_complete(
#     573     self.ainsert(
#     574         input, split_by_character, split_by_character_only, ids, file_paths
#     575     )
#     576 )
#
# File ~/Harish_MAC/Learning/Projects/GenAI/.venv/lib/python3.13/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~/.local/share/uv/python/cpython-3.13.3-macos-x86_64-none/lib/python3.13/asyncio/futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File ~/.local/share/uv/python/cpython-3.13.3-macos-x86_64-none/lib/python3.13/asyncio/tasks.py:304, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     300 try:
#     301     if exc is None:
#     302         # We use the `send` method directly, because coroutines
#     303         # don't have `__iter__` and `__next__` methods.
# --> 304         result = coro.send(None)
#     305     else:
#     306         result = coro.throw(exc)
#
# File ~/Harish_MAC/Learning/Projects/GenAI/.venv/lib/python3.13/site-packages/lightrag/lightrag.py:597, in LightRAG.ainsert(self, input, split_by_character, split_by_character_only, ids, file_paths)
#     578 async def ainsert(
#     579     self,
#     580     input: str | list[str],
#    (...)    584     file_paths: str | list[str] | None = None,
#     585 ) -> None:
#     586     """Async Insert documents with checkpoint support
#     587
#     588     Args:
#    (...)    595         file_paths: list of file paths corresponding to each document, used for citation
#     596     """
# --> 597     await self.apipeline_enqueue_documents(input, ids, file_paths)
#     598     await self.apipeline_process_enqueue_documents(
#     599         split_by_character, split_by_character_only
#     600     )
#
# File ~/Harish_MAC/Learning/Projects/GenAI/.venv/lib/python3.13/site-packages/lightrag/lightrag.py:783, in LightRAG.apipeline_enqueue_documents(self, input, ids, file_paths)
#     781 all_new_doc_ids = set(new_docs.keys())
#     782 # Exclude IDs of documents that are already in progress
# --> 783 unique_new_doc_ids = await self.doc_status.filter_keys(all_new_doc_ids)
#     785 # Log ignored document IDs
#     786 ignored_ids = [
#     787     doc_id for doc_id in unique_new_doc_ids if doc_id not in new_docs
#     788 ]
#
# File ~/Harish_MAC/Learning/Projects/GenAI/.venv/lib/python3.13/site-packages/lightrag/kg/json_doc_status_impl.py:56, in JsonDocStatusStorage.filter_keys(self, keys)
#      54 async def filter_keys(self, keys: set[str]) -> set[str]:
#      55     """Return keys that should be processed (not in storage or not successfully processed)"""
# ---> 56     async with self._storage_lock:
#      57         return set(keys) - set(self._data.keys())
#
# TypeError: 'NoneType' object does not support the asynchronous context manager protocol

# %%
query = "How many employees does Insurellm have?"

result = lightrag.query(
               query,
               param=QueryParam(mode="global")
               )
Markdown(result)
# Out:
# Sorry, I'm not able to provide an answer to that question.[no-context]
